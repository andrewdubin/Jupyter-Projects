# %%
import pandas as pd
import numpy as np
from pandas import read_html, DataFrame, Series

# %%
url = 'https://liquipedia.net/counterstrike/HLTV/Top_20_Players'
dframelist = pd.io.html.read_html(url)
dframe = dframelist[3]
dframe
# Out:
#    2019                                                    \
#       #                               Player Team Article
# 0     1              Mathieu "ZywOo" Herbaut  NaN    Link
# 1     2         Oleksandr "s1mple" Kostyliev  NaN    Link
# 2     3              Nicolai "device" Reedtz  NaN    Link
# 3     4         Jonathan "EliGE" Jablonowski  NaN    Link
# 4     5                   Emil "Magisk" Reif  NaN    Link
# ..  ...                                  ...  ...     ...
# 59   16             Ioann "Edward" Sukhariev  NaN    Link
# 60   17        Edouard "SmithZz" Dubourdeaux  NaN    Link
# 61   18            Peter "dupreeh" Rasmussen  NaN    Link
# 62   19  Jarosław "pashaBiceps" Jarząbkowski  NaN    Link
# 63   20             Andreas "Xyp9x" Højsleth  NaN    Link
#
#                                    2018                \
#                                  Player  Team Article
# 0          Oleksandr "s1mple" Kostyliev   NaN    Link
# ...

# %%
dframe2019 = DataFrame(dframe['2019'][0:20],columns=['Year','#','Player','Team','Nation'])
dframe2019['Year'] = 2019
dframe2019.rename(columns={'#':"Rank"},inplace=True)
dframe2019.set_index(['Year','Rank'],inplace=True)
dframe2019['Team'] = ['Vitality','NaVi','Astralis','Team Liquid','Astralis','NaVi','Team Liquid','Evil Geniuses',
                     'Team Liquid','mousesports','FaZe','mousesports','ENCE','Astralis','100 Thieves','Astralis','Fnatic',
                     'Evil Geniuses','Fnatic','Evil Geniuses']
dframe2019['Nation'] = ['France','Ukraine','Denmark','USA','Denmark','Russia','Canada','USA','Canada','Estonia','Bosnia',
                        'Turkey','Finland','Denmark','Australia','Denmark','Sweden','Bulgaria','Sweden','USA']
dframe2019
# Out:
#                                  Player           Team     Nation
# Year Rank
# 2019 1          Mathieu "ZywOo" Herbaut       Vitality     France
#      2     Oleksandr "s1mple" Kostyliev           NaVi    Ukraine
#      3          Nicolai "device" Reedtz       Astralis    Denmark
#      4     Jonathan "EliGE" Jablonowski    Team Liquid        USA
#      5               Emil "Magisk" Reif       Astralis    Denmark
#      6      Denis "electronic" Sharipov           NaVi     Russia
#      7             Keith "NAF" Markovic    Team Liquid     Canada
#      8         Vincent "Brehze" Cayonte  Evil Geniuses        USA
#      9      Russel "Twistzz" Van Dulken    Team Liquid     Canada
#      10               Robin "ropz" Kool    mousesports    Estonia
#      11             Nikola "NiKo" Kovač           FaZe     Bosnia
#      12              Özgür "woxic" Eker    mousesports     Turkey
#      13              Jere "sergej" Salo           ENCE    Finland
# ...

# %%
dframe2018 = DataFrame(dframe['2018'][0:20],columns=['Year','Rank','Player','Team','Nation'])
dframe2018['Rank'] = np.arange(1,21)
dframe2018['Year'] = 2018
dframe2018.set_index(['Year','Rank'],inplace=True)
dframe2018['Team'] = ['NaVi','Astralis','FaZe','NaVi','Astralis','Team Liquid','Astralis','Astralis',
                     'Fnatic','MIBR','FaZe','Team Liquid','Astralis','mousesports','Team Liquid','mousesports','Cloud 9',
                      'FaZe','mousesports','North']
dframe2018['Nation'] = ['Ukraine','Denmark','Bosnia','Russia','Denmark','USA','Denmark','Denmark','Sweden','Brazil','Slovakia',
                       'USA','Denmark','Czechia','USA','Finland','USA','Norway','Estonia','Denmark']
dframe2018
# Out:
#                                   Player         Team    Nation
# Year Rank
# 2018 1      Oleksandr "s1mple" Kostyliev         NaVi   Ukraine
#      2           Nicolai "device" Reedtz     Astralis   Denmark
#      3               Nikola "NiKo" Kovač         FaZe    Bosnia
#      4       Denis "electronic" Sharipov         NaVi    Russia
#      5         Peter "dupreeh" Rasmussen     Astralis   Denmark
#      6              Keith "NAF" Markovic  Team Liquid       USA
#      7                Emil "Magisk" Reif     Astralis   Denmark
#      8          Lukas "gla1ve" Rossander     Astralis   Denmark
#      9          Freddy "KRIMZ" Johansson       Fnatic    Sweden
#      10         Marcelo "coldzera" David         MIBR    Brazil
#      11       Ladislav "GuardiaN" Kovács         FaZe  Slovakia
#      12      Russel "Twistzz" Van Dulken  Team Liquid       USA
#      13         Andreas "Xyp9x" Højsleth     Astralis   Denmark
# ...

# %%
dframe2017 = DataFrame(dframe['2017'][0:20],columns=['Year','Rank','Player','Team','Nation'])
dframe2017['Rank'] = np.arange(1,21)
dframe2017['Year'] = 2017
dframe2017.set_index(['Year','Rank'],inplace=True)
dframe2017['Team'] = ['SK','FaZe','SK','FaZe','Astralis','SK','G2','NaVi',
                      'FaZe','Astralis','Gambit','Team Liquid','Astralis','North','Astralis','mousesports',
                     'Gambit','Immortals','FaZe','Virtus Pro']
dframe2017['Nation'] = ['Brazil','Bosnia','Brazil','Norway','Denmark','Brazil','France','Ukraine','Slovakia','Denmark',
                        'Kazakhstan','USA','Denmark','Denmark','Denmark','Czechia','Kazakhstan','Brazil','Sweden','Poland']
dframe2017
# Out:
#                                  Player         Team      Nation
# Year Rank
# 2017 1         Marcelo "coldzera" David           SK      Brazil
#      2              Nikola "NiKo" Kovač         FaZe      Bosnia
#      3         Fernando "fer" Alvarenga           SK      Brazil
#      4            Håvard "rain" Nygaard         FaZe      Norway
#      5          Nicolai "device" Reedtz     Astralis     Denmark
#      6          Gabriel "FalleN" Toledo           SK      Brazil
#      7            Kenny "kennyS" Schrub           G2      France
#      8     Oleksandr "s1mple" Kostyliev         NaVi     Ukraine
#      9       Ladislav "GuardiaN" Kovács         FaZe    Slovakia
#      10       Peter "dupreeh" Rasmussen     Astralis     Denmark
#      11          Abay "HObbit" Khasenov       Gambit  Kazakhstan
#      12    Jonathan "EliGE" Jablonowski  Team Liquid         USA
#      13        Andreas "Xyp9x" Højsleth     Astralis     Denmark
# ...

# %%
dframe2016 = DataFrame(dframe['2019'][22:42],columns=['Year','#','Player','Team','Nation'])
dframe2016.rename(columns={'#':"Rank"},inplace=True)
dframe2016['Year'] = 2016
dframe2016.set_index(['Year','Rank'],inplace=True)
dframe2016['Team'] = ['Luminosity','Luminosity','Astralis','NaVi','Virtus Pro','G2','NiP',
          'Fnatic','G2','Fnatic','mousesports','NaVi','EnVyUs','Dignitas','Luminosity','Astralis',
          'NaVi','NiP','Luminosity','Fnatic']
dframe2016['Nation'] = ['Brazil','Brazil','Denmark','Ukraine','Poland','France','Sweden','Sweden','Belgium','Sweden','Bosnia',
                       'Russia','France','Denmark','Brazil','Denmark','Slovakia','Sweden','Brazil','Sweden']
dframe2016
# Out:
#                                     Player         Team    Nation
# Year Rank
# 2016 1            Marcelo "coldzera" David   Luminosity    Brazil
#      2             Gabriel "FalleN" Toledo   Luminosity    Brazil
#      3             Nicolai "device" Reedtz     Astralis   Denmark
#      4        Oleksandr "s1mple" Kostyliev         NaVi   Ukraine
#      5           Janusz "Snax" Pogorzelski   Virtus Pro    Poland
#      6             Richard "shox" Papillon           G2    France
#      7            Patrik "f0rest" Lindberg          NiP    Sweden
#      8          Olof "olofmeister" Kajbjer       Fnatic    Sweden
#      9             Adil "ScreaM" Benrlitom           G2   Belgium
#      10           Robin "flusha" Rönnquist       Fnatic    Sweden
#      11                Nikola "NiKo" Kovač  mousesports    Bosnia
#      12             Egor "flamie" Vasilyev         NaVi    Russia
#      13              Kenny "kennyS" Schrub       EnVyUs    France
# ...

# %%
dframe2015 = DataFrame(dframe['2018'][22:42],columns=['Year','Rank','Player','Team','Nation'])
dframe2015['Rank'] = np.arange(1,21)
dframe2015['Year'] = 2015
dframe2015.set_index(['Year','Rank'],inplace=True)
dframe2015['Team'] = ['Fnatic','NaVi','TSM','Virtus Pro','Fnatic','EnVyUs','Fnatic','EnVyUs','EnVyUs','Fnatic',
                     'NiP','TSM','Titan','NaVi','TSM','NiP','Virtus Pro','EnVyUs',
                     'NiP','Cloud 9']
dframe2015['Nation'] = ['Sweden','Slovakia','Denmark','Poland','Sweden','France','Sweden','France','France','Sweden','Sweden',
                       'Denmark','France','Russia','Denmark','Sweden','Poland','France','Finland','USA']
dframe2015
# Out:
#                                     Player        Team    Nation
# Year Rank
# 2015 1          Olof "olofmeister" Kajbjer      Fnatic    Sweden
#      2          Ladislav "GuardiaN" Kovács        NaVi  Slovakia
#      3             Nicolai "device" Reedtz         TSM   Denmark
#      4           Janusz "Snax" Pogorzelski  Virtus Pro    Poland
#      5            Robin "flusha" Rönnquist      Fnatic    Sweden
#      6               Kenny "kennyS" Schrub      EnVyUs    France
#      7            Freddy "KRIMZ" Johansson      Fnatic    Sweden
#      8        Vincent "Happy" Schopenhauer      EnVyUs    France
#      9               Nathan "NBK-" Schmitt      EnVyUs    France
#      10               Jesper "JW" Wecksell      Fnatic    Sweden
#      11    Christopher "GeT_RiGhT" Alesund         NiP    Sweden
#      12          Peter "dupreeh" Rasmussen         TSM   Denmark
#      13            Richard "shox" Papillon       Titan    France
# ...

# %%
dframe2014 = DataFrame(dframe['2017'][22:42],columns=['Year','Rank','Player','Team','Nation'])
dframe2014['Rank'] = np.arange(1,21)
dframe2014['Year'] = 2014
dframe2014.set_index(['Year','Rank'],inplace=True)
dframe2014['Team'] = ['NiP','Fnatic','Virtus Pro','Virtus Pro','Fnatic','Titan','NiP','LDLC','Fnatic',
                     'LDLC','NaVi','Fnatic','Virtus Pro','NiP','Titan','Dignitas','LDLC','iBUYPOWER',
                      'LDLC','Dignitas']
dframe2014['Nation'] = ['Sweden','Sweden','Poland','Poland','Sweden','France','Sweden','France','Sweden','France','Slovakia',
                       'Sweden','Poland','Sweden','France','Denmark','France','USA','France','Denmark']
dframe2014
# Out:
#                                         Player        Team    Nation
# Year Rank
# 2014 1         Christopher "GeT_RiGhT" Alesund         NiP    Sweden
#      2                Robin "flusha" Rönnquist      Fnatic    Sweden
#      3     Jarosław "pashaBiceps" Jarząbkowski  Virtus Pro    Poland
#      4               Janusz "Snax" Pogorzelski  Virtus Pro    Poland
#      5                    Jesper "JW" Wecksell      Fnatic    Sweden
#      6                   Kenny "kennyS" Schrub       Titan    France
#      7                Patrik "f0rest" Lindberg         NiP    Sweden
#      8                 Richard "shox" Papillon        LDLC    France
#      9                Freddy "KRIMZ" Johansson      Fnatic    Sweden
#      10                Vincent "Happy" Cervoni        LDLC    France
#      11             Ladislav "GuardiaN" Kovács        NaVi  Slovakia
#      12             Olof "olofmeister" Kajbjer      Fnatic    Sweden
# ...

# %%
dframe2013 = DataFrame(dframe['2019'][44:64],columns=['Year','#','Player','Team','Nation'])
dframe2013['Year'] = 2013
dframe2013.rename(columns={'#':"Rank"},inplace=True)
dframe2013.set_index(['Year','Rank'],inplace=True)
dframe2013['Team'] = ['NiP','NiP','VeryGames','Virtus Pro','VeryGames','NiP','VeryGames','Fnatic','Complexity','NaVi',
                   'NiP','VeryGames','Fnatic','Western Wolves','NaVi','NaVi','VeryGames','Copenhagen Wolves','ESC Gaming',
                   'Copenhagen Wolves']
dframe2013['Nation'] = ['Sweden','Sweden','France','Russia','France','Sweden','Belgium','Sweden','USA','Slovakia','Sweden',
                        'France','Sweden','Denmark','Ukraine','Ukraine','France','Denmark','Poland','Denmark']
dframe2013
# Out:
#                                         Player               Team    Nation
# Year Rank
# 2013 1         Christopher "GeT_RiGhT" Alesund                NiP    Sweden
#      2                Patrik "f0rest" Lindberg                NiP    Sweden
#      3                 Richard "shox" Papillon          VeryGames    France
#      4                Mihail "Dosia" Stolyarov         Virtus Pro    Russia
#      5                    Nathan "NBK" Schmitt          VeryGames    France
#      6                Richard "Xizt" Landström                NiP    Sweden
#      7                 Adil "ScreaM" Benrlitom          VeryGames   Belgium
#      8                    Jesper "JW" Wecksell             Fnatic    Sweden
#      9                   Spencer "Hiko" Martin         Complexity       USA
#      10             Ladislav "GuardiaN" Kovács               NaVi  Slovakia
#      11                 Adam "friberg" Friberg                NiP    Sweden
# ...

# %%
totaldframe = pd.concat([dframe2013,dframe2014,dframe2015,dframe2016,dframe2017,dframe2018,dframe2019])
totaldframe
# Out:
#                                     Player           Team    Nation
# Year Rank
# 2013 1     Christopher "GeT_RiGhT" Alesund            NiP    Sweden
#      2            Patrik "f0rest" Lindberg            NiP    Sweden
#      3             Richard "shox" Papillon      VeryGames    France
#      4            Mihail "Dosia" Stolyarov     Virtus Pro    Russia
#      5                Nathan "NBK" Schmitt      VeryGames    France
# ...                                    ...            ...       ...
# 2019 16          Peter "dupreeh" Rasmussen       Astralis   Denmark
#      17           Freddy "KRIMZ" Johansson         Fnatic    Sweden
#      18           Cvetelin "CeRq" Dimitrov  Evil Geniuses  Bulgaria
#      19            Ludvig "Brollan" Brolin         Fnatic    Sweden
#      20               Ethan "Ethan" Arnold  Evil Geniuses       USA
#
# [140 rows x 3 columns]

# %%
totaldframe[totaldframe.Team=='Cloud 9']
# Out:
#                              Player     Team Nation
# Year Rank
# 2015 20    Tyler "Skadoodle" Latham  Cloud 9    USA
# 2018 17      Timothy "autimatic" Ta  Cloud 9    USA
